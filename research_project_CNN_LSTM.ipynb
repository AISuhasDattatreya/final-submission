# %% [markdown]
# ## Importing Libraries

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np
import os
import warnings
import tensorflow as tf
from keras import backend as K
from keras import optimizers
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,Reshape, Conv1D, MaxPooling1D, Flatten, Dense, LSTM, Dropout
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Providing Datapath of the mat files obtained from kaggle

# %%
datapath = '/content/drive/MyDrive/archive_1/'
#https://www.kaggle.com/datasets/mkachuee/BloodPressureDataset

# %% [markdown]
# ## Defining Functions to load full and partial list of mat files

# %%
def load_data_partial(filename):
    mat_contents = sio.loadmat(filename)
    return mat_contents

# %%
def load_data(fileDir, exercise):
    word = exercise.lower()
    file_path_list = []
    valid_file_extensions = [".mat"]
    valid_file_extensions = [item.lower() for item in valid_file_extensions]


    for file in os.listdir(fileDir):
        extension = os.path.splitext(file)[1]
        if extension.lower() not in valid_file_extensions:
            continue
        file_path_list.append(os.path.join(fileDir, file))

    Data = []
    for path in file_path_list:
        base=os.path.basename(path)
        base = os.path.splitext(base)[0]
        if word in base:
            print(fileDir+'/%s'%(base))
            mat_contents = sio.loadmat(fileDir+'/%s'%(base))
            val = mat_contents['p']
            total_array = val[0,:] #assigning an array
            Data.append(total_array)

    return Data

# %% [markdown]
# ### Loading the MAT files

# %%
word = 'part'
total_data = load_data(datapath, word)
x =load_data_partial(datapath+str('part_1.mat'))
# Out:
# /content/drive/MyDrive/archive_1//part_1

# %% [markdown]
# ## Feature Extraction: Extracting PPG ,ECG and ABP values from total_data

# %%
PPG = []
ABP = []
ECG = []
for i in range((len(total_data))):
    for j in range(len(total_data[i])):
        k = len(total_data[i][j][0,:])
        for n in range(k//1000):
            ppg = (total_data[i][j][0,(n*1000):(n*1000)+1000]) # Extracting PPG values
            abp = (total_data[i][j][1,(n*1000):(n*1000)+1000]) #Extracting ABP values
            ecg = (total_data[i][j][2,(n*1000):(n*1000)+1000]) #Extracting ECG values
            PPG.append(ppg)
            ABP.append(abp)
            ECG.append(ecg)

# Converting list of PPG,ECG and ABP as array
PPG = np.asarray(PPG)
ABP = np.asarray(ABP)
ECG = np.asarray(ECG)

# %% [markdown]
# ### Plotting graphs for PPG,ECG and ABP signals

# %%
# plotting sample  ppg, ecg and bp signals
fig, ax = plt.subplots(3,1, figsize=(6,6), sharex=True)
y = 1000
ax[0].set_title('Photoplethysmography (PPG) graph', fontsize=12)
ax[0].set_ylabel('Signal Value')
ax[0].plot(PPG[y,:], c = 'dodgerblue')

ax[1].set_title('Electrocardiogram (ECG) graph', fontsize=12)
ax[1].set_ylabel('Signal Value')
ax[1].plot(ECG[y,:], c='darkorange')

ax[2].set_title('Arterial Blood Pressure (ABP) graph', fontsize=12)
ax[2].set_ylabel('Signal Value')
ax[2].set_xlabel('Sample size')
ax[2].plot(ABP[y,:], c = 'red')

# %% [markdown]
# ### Correlation Estimation

# %%
from scipy.stats import pearsonr

# Calculate the correlation between ECG and PPG signals
ecg_ppg_correlation, _ = pearsonr(ECG[:1000].flatten(), PPG[:1000].flatten())
print("Correlation between ECG and PPG signals:", ecg_ppg_correlation)

# Calculate the correlation between ECG and BP signals
ecg_bp_correlation, _ = pearsonr(ECG[:1000].flatten(), ABP[:1000].flatten())
print("Correlation between ECG and ABP signals:", ecg_bp_correlation)

# Calculate the correlation between PPG and BP signals
ppg_bp_correlation, _ = pearsonr(PPG[:1000].flatten(), ABP[:1000].flatten())
print("Correlation between PPG and ABP signals:", ppg_bp_correlation)
# Out:
# Correlation between ECG and PPG signals: -0.27346160018394666
# Correlation between ECG and ABP signals: 0.059160138825351025
# Correlation between PPG and ABP signals: -0.028087942051436457

# %% [markdown]
# ## Splitting the data into 70% train and 30% test
#
# **Input** : PPG values
#
# **Output**:  ABP and ECG Values

# %%
X_train_PPG, X_test_PPG, y_train_ABP, y_test_ABP, y_train_ECG, y_test_ECG = train_test_split(
    PPG, ABP, ECG, test_size=0.30)

# %%
X_train_PPG_reshape = np.reshape(X_train_PPG, (X_train_PPG.shape[0], X_train_PPG.shape[1], 1))

# %%
input_shape = (X_train_PPG_reshape.shape[1],1)
inputs = Input(shape=input_shape)

# Add the first convolutional layer
x = Conv1D(filters=256, kernel_size=3, activation='relu')(inputs)
x = MaxPooling1D(pool_size=2)(x)

# Add additional convolutional layers as needed
x = Conv1D(filters=128, kernel_size=3, activation='relu')(x)
x = MaxPooling1D(pool_size=2)(x)

# Add additional convolutional layers as needed
x = Conv1D(filters=64, kernel_size=3, activation='relu')(x)
x = MaxPooling1D(pool_size=2)(x)

# Flatten the output for further processing
# x = Flatten()(x)
x = Reshape((-1, 64))(x)
x = LSTM(100,return_sequences=False)(x)

# Branch 1 for output 1
bp_output = Dense(units=1000, activation='linear',name='bp_out')(x)

# Branch 2 for output 2
ecg_output = Dense(units=1000, activation='linear',name='ecg_out')(x)

model = Model(inputs=inputs, outputs=[bp_output, ecg_output])

# %%
img_file = './model-research-CNN-LSTM.png'
tf.keras.utils.plot_model(model, to_file=img_file, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model.compile(optimizer='adam',
              loss={'bp_out': 'mse', 'ecg_out': 'mse'},
              metrics={'bp_out': tf.keras.metrics.RootMeanSquaredError(),
                       'ecg_out': tf.keras.metrics.RootMeanSquaredError()})
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 1000, 1)]            0         []
#
#  conv1d (Conv1D)             (None, 998, 256)             1024      ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 499, 256)             0         ['conv1d[0][0]']
#  D)
#
#  conv1d_1 (Conv1D)           (None, 497, 128)             98432     ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPoolin  (None, 248, 128)             0         ['conv1d_1[0][0]']
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 246, 64)              24640     ['max_pooling1d_1[0][0]']
#
#  max_pooling1d_2 (MaxPoolin  (None, 123, 64)              0         ['conv1d_2[0][0]']
#  g1D)
#
#  reshape (Reshape)           (None, 123, 64)              0         ['max_pooling1d_2[0][0]']
#
#  lstm (LSTM)                 (None, 100)                  66000     ['reshape[0][0]']
#
#  bp_out (Dense)              (None, 1000)                 101000    ['lstm[0][0]']
#
#  ecg_out (Dense)             (None, 1000)                 101000    ['lstm[0][0]']
#
# ==================================================================================================
# Total params: 392096 (1.50 MB)
# Trainable params: 392096 (1.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Training a CNN-LSTM model without Normalized signal values

# %%
model.fit(X_train_PPG_reshape, [y_train_ABP, y_train_ECG], batch_size=1024, epochs=20, verbose = 1)
# Out:
# Epoch 1/20
# 22/22 [==============================] - 43s 2s/step - loss: 9022.1738 - bp_out_loss: 9021.8135 - ecg_out_loss: 0.3609 - bp_out_root_mean_squared_error: 94.9832 - ecg_out_root_mean_squared_error: 0.6007
# Epoch 2/20
# 22/22 [==============================] - 40s 2s/step - loss: 8543.6465 - bp_out_loss: 8543.2959 - ecg_out_loss: 0.3511 - bp_out_root_mean_squared_error: 92.4300 - ecg_out_root_mean_squared_error: 0.5925
# Epoch 3/20
# 22/22 [==============================] - 40s 2s/step - loss: 8094.2119 - bp_out_loss: 8093.8633 - ecg_out_loss: 0.3486 - bp_out_root_mean_squared_error: 89.9659 - ecg_out_root_mean_squared_error: 0.5904
# Epoch 4/20
# 22/22 [==============================] - 40s 2s/step - loss: 7683.9697 - bp_out_loss: 7683.6216 - ecg_out_loss: 0.3485 - bp_out_root_mean_squared_error: 87.6563 - ecg_out_root_mean_squared_error: 0.5903
# Epoch 5/20
# 22/22 [==============================] - 40s 2s/step - loss: 7302.9561 - bp_out_loss: 7302.6084 - ecg_out_loss: 0.3482 - bp_out_root_mean_squared_error: 85.4553 - ecg_out_root_mean_squared_error: 0.5901
# Epoch 6/20
# 22/22 [==============================] - 40s 2s/step - loss: 6944.6230 - bp_out_loss: 6944.2739 - ecg_out_loss: 0.3484 - bp_out_root_mean_squared_error: 83.3323 - ecg_out_root_mean_squared_error: 0.5902
# Epoch 7/20
# 22/22 [==============================] - 40s 2s/step - loss: 6605.4248 - bp_out_loss: 6605.0771 - ecg_out_loss: 0.3485 - bp_out_root_mean_squared_error: 81.2716 - ecg_out_root_mean_squared_error: 0.5903
# Epoch 8/20
# 22/22 [==============================] - 40s 2s/step - loss: 6283.1450 - bp_out_loss: 6282.7969 - ecg_out_loss: 0.3485 - bp_out_root_mean_squared_error: 79.2641 - ecg_out_root_mean_squared_error: 0.5904
# Epoch 9/20
# 22/22 [==============================] - 40s 2s/step - loss: 5976.4551 - bp_out_loss: 5976.1074 - ecg_out_loss: 0.3484 - bp_out_root_mean_squared_error: 77.3053 - ecg_out_root_mean_squared_error: 0.5902
# Epoch 10/20
# 22/22 [==============================] - 40s 2s/step - loss: 5684.2583 - bp_out_loss: 5683.9097 - ecg_out_loss: 0.3485 - bp_out_root_mean_squared_error: 75.3917 - ecg_out_root_mean_squared_error: 0.5904
# Epoch 11/20
# 22/22 [==============================] - 40s 2s/step - loss: 5405.7407 - bp_out_loss: 5405.3921 - ecg_out_loss: 0.3482 - bp_out_root_mean_squared_error: 73.5214 - ecg_out_root_mean_squared_error: 0.5900
# Epoch 12/20
# 22/22 [==============================] - 40s 2s/step - loss: 5140.2349 - bp_out_loss: 5139.8857 - ecg_out_loss: 0.3490 - bp_out_root_mean_squared_error: 71.6930 - ecg_out_root_mean_squared_error: 0.5907
# Epoch 13/20
# 22/22 [==============================] - 40s 2s/step - loss: 4887.2192 - bp_out_loss: 4886.8701 - ecg_out_loss: 0.3492 - bp_out_root_mean_squared_error: 69.9062 - ecg_out_root_mean_squared_error: 0.5909
# Epoch 14/20
# 22/22 [==============================] - 40s 2s/step - loss: 4646.0938 - bp_out_loss: 4645.7451 - ecg_out_loss: 0.3490 - bp_out_root_mean_squared_error: 68.1597 - ecg_out_root_mean_squared_error: 0.5908
# Epoch 15/20
# 22/22 [==============================] - 40s 2s/step - loss: 4416.4297 - bp_out_loss: 4416.0811 - ecg_out_loss: 0.3485 - bp_out_root_mean_squared_error: 66.4536 - ecg_out_root_mean_squared_error: 0.5903
# Epoch 16/20
# 22/22 [==============================] - 40s 2s/step - loss: 4197.8218 - bp_out_loss: 4197.4731 - ecg_out_loss: 0.3482 - bp_out_root_mean_squared_error: 64.7879 - ecg_out_root_mean_squared_error: 0.5901
# Epoch 17/20
# 22/22 [==============================] - 40s 2s/step - loss: 3989.6340 - bp_out_loss: 3989.2854 - ecg_out_loss: 0.3484 - bp_out_root_mean_squared_error: 63.1608 - ecg_out_root_mean_squared_error: 0.5902
# Epoch 18/20
# 22/22 [==============================] - 40s 2s/step - loss: 3791.8203 - bp_out_loss: 3791.4722 - ecg_out_loss: 0.3484 - bp_out_root_mean_squared_error: 61.5749 - ecg_out_root_mean_squared_error: 0.5902
# Epoch 19/20
# 22/22 [==============================] - 40s 2s/step - loss: 3603.8425 - bp_out_loss: 3603.4934 - ecg_out_loss: 0.3492 - bp_out_root_mean_squared_error: 60.0291 - ecg_out_root_mean_squared_error: 0.5909
# Epoch 20/20
# 22/22 [==============================] - 40s 2s/step - loss: 3425.2488 - bp_out_loss: 3424.9004 - ecg_out_loss: 0.3484 - bp_out_root_mean_squared_error: 58.5226 - ecg_out_root_mean_squared_error: 0.5903

# %%
X_test_PPG_reshape = np.reshape(X_test_PPG, (X_test_PPG.shape[0], X_test_PPG.shape[1], 1))

# %% [markdown]
# ### Evaluating CNN-LSTM model without Normalization for ABP values

# %%
#Predicting on the test set using the LSTM model
CNN_LSTM_predictions = model.predict(X_test_PPG_reshape)
rmse = tf.keras.metrics.RootMeanSquaredError()
rmse.update_state(y_test_ABP, CNN_LSTM_predictions[0])
print(f'CNN-LSTM Model RMSE for ABP: {rmse.result().numpy()}')

# MAE for LSTM Model
MAE= tf.keras.metrics.MeanAbsoluteError()
MAE.update_state(y_test_ABP, CNN_LSTM_predictions[0])
print(f'CNN-LSTM Model MAE for ABP: {MAE.result().numpy()}')
# Out:
# 301/301 [==============================] - 10s 31ms/step
# CNN-LSTM Model RMSE for ABP: 57.94504928588867
# CNN-LSTM Model MAE for ABP: 50.510353088378906

# %%
# Visualize predicted BP and the True BP for LSTM model
plt.title("===True ABP values Vs Predicted ABP values in CNN-LSTM Model===")
plt.xlabel('Number of samples taken')
plt.ylabel('ABP values')
plt.plot(y_test_ABP[1000]) #only plotting 100 samples
plt.plot(CNN_LSTM_predictions[0][1000])
plt.legend(['True_BP', 'Predicted_BP'])

# %% [markdown]
# ### Evaluating CNN-LSTM model without Normalization for ECG values

# %%
rmse = tf.keras.metrics.RootMeanSquaredError()
rmse.update_state(y_test_ECG, CNN_LSTM_predictions[1])
print(f'LSTM Model RMSE for ECG values: {rmse.result().numpy()}')

MAE= tf.keras.metrics.MeanAbsoluteError()
MAE.update_state(y_test_ECG, CNN_LSTM_predictions[1])
print(f'LSTM Model MAE for ECG values: {MAE.result().numpy()}')
# Out:
# LSTM Model RMSE for ECG values: 0.5906296968460083
# LSTM Model MAE for ECG values: 0.47535252571105957

# %%
plt.title("===True ECG values Vs Predicted ECG values in CNN-LSTM Model===")
plt.xlabel('Number of samples taken')
plt.ylabel('ECG values')
plt.plot(y_test_ECG[1000]) #only plotting 100 samples
plt.plot(CNN_LSTM_predictions[1][1000])
plt.legend(['True_ECG', 'Predicted_ECG'])

# %% [markdown]
# ## Defining Function to Normalize the PPG and ABP values

# %%
def normalise(x):
    normalised = (x-min(x))/(max(x)-min(x))
    return normalised

def scale_abp(x):
    normalised = x/200
    return normalised

def normalise_abp(abp, x_max, x_min):
    normalised = (abp-x_min)/(x_max-x_min)
    return normalised

def abp_maxmin_value(x):
    max_x = []
    min_x = []
    for i in range(len(x)):
        for j in range(len(x[i])):
            max_x.append(max(x[i][j][1,:]))
            min_x.append(min(x[i][j][1,:]))
    x_max = max(max_x)
    x_min = min(min_x)
    return x_max, x_min

# %% [markdown]
# ### Checking Minimum and Maximum values in total_data

# %%
x_max, x_min = abp_maxmin_value(total_data)
print(x_max, x_min)
x_max = 200.0
x_min = 50.0
# Out:
# 199.90934525391145 50.01623903864891

# %% [markdown]
# ## Feature Extraction and Feature Scaling: Extracting PPG ,ECG and ABP values from total_data and normalizing them

# %%
# #Data Pre-processing
# # Extracting signal data Feature-extraction
PPG_N = []
ABP_N = []
ECG_N = []
i=0
for j in range(len(total_data[i])):
    k = len(total_data[i][j][0,:])
    for n in range(k//1000):
        ppg_n = normalise(total_data[i][j][0,(n*1000):(n*1000)+1000])
        abp_n = normalise_abp(total_data[i][j][1,(n*1000):(n*1000)+1000], x_max, x_min)
        ecg_n = normalise(total_data[i][j][2,(n*1000):(n*1000)+1000])
        PPG_N.append(ppg_n)
        ABP_N.append(abp_n)
        ECG_N.append(ecg_n)

PPG_N = np.asarray(PPG_N)
ABP_N = np.asarray(ABP_N)
ECG_N = np.asarray(ECG_N)

# %% [markdown]
# ### Plotting graphs for Normalized PPG,ECG and ABP signals

# %%
# ##plotting sample normalized ppg, ecg and bp signals
# ##using a sample size of 125
fig, ax = plt.subplots(3,1, figsize=(6,6), sharex=True)
y = 1000
ax[0].set_title('Normalized Photoplethysmography (PPG) graph', fontsize=12)
ax[0].set_ylabel('Signal Value')
ax[0].plot(PPG_N[y,:], c = 'dodgerblue')

ax[1].set_title('Normalized Electrocardiogram (ECG) graph', fontsize=12)
ax[1].set_ylabel('Signal Value')
ax[1].plot(ECG_N[y,:], c='darkorange')

ax[2].set_title('Normalized Arterial Blood Pressure (ABP) graph', fontsize=12)
ax[2].set_ylabel('Signal Value')
ax[2].set_xlabel('Sample size')
ax[2].plot(ABP_N[y,:], c = 'red')

# %% [markdown]
# ## Splitting the normalized data into 70% train and 30% test
# **Input** : *Normalized PPG values*
#
# **Output**: *Normalized ABP values*

# %%
X_train_PPG_N, X_test_PPG_N, y_train_ABP_N, y_test_ABP_N, y_train_ECG_N, y_test_ECG_N = train_test_split(
    PPG_N, ABP_N, ECG_N, test_size=0.30)

# %%
X_train_PPG_N_reshape = np.reshape(X_train_PPG_N, (X_train_PPG_N.shape[0], X_train_PPG_N.shape[1], 1))

# %%
X_test_PPG_N_reshape =np.reshape(X_test_PPG_N, (X_test_PPG_N.shape[0] ,X_test_PPG_N.shape[1],1))

# %% [markdown]
# ### Training the CNN-LSTM Model with Normalized values

# %%
model.fit(X_train_PPG_N_reshape, [y_train_ABP_N, y_train_ECG_N], batch_size=1024, epochs=20, verbose = 1)
# Out:
# Epoch 1/20
# 22/22 [==============================] - 40s 2s/step - loss: 1667.8776 - bp_out_loss: 1667.8380 - ecg_out_loss: 0.0393 - bp_out_root_mean_squared_error: 40.8392 - ecg_out_root_mean_squared_error: 0.1982
# Epoch 2/20
# 22/22 [==============================] - 40s 2s/step - loss: 1094.5267 - bp_out_loss: 1094.4868 - ecg_out_loss: 0.0399 - bp_out_root_mean_squared_error: 33.0830 - ecg_out_root_mean_squared_error: 0.1998
# Epoch 3/20
# 22/22 [==============================] - 40s 2s/step - loss: 2.9600 - bp_out_loss: 2.8812 - ecg_out_loss: 0.0788 - bp_out_root_mean_squared_error: 1.6974 - ecg_out_root_mean_squared_error: 0.2807
# Epoch 4/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.1159 - bp_out_loss: 0.0724 - ecg_out_loss: 0.0435 - bp_out_root_mean_squared_error: 0.2691 - ecg_out_root_mean_squared_error: 0.2086
# Epoch 5/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0771 - bp_out_loss: 0.0392 - ecg_out_loss: 0.0379 - bp_out_root_mean_squared_error: 0.1980 - ecg_out_root_mean_squared_error: 0.1947
# Epoch 6/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0744 - bp_out_loss: 0.0375 - ecg_out_loss: 0.0369 - bp_out_root_mean_squared_error: 0.1937 - ecg_out_root_mean_squared_error: 0.1921
# Epoch 7/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0739 - bp_out_loss: 0.0371 - ecg_out_loss: 0.0368 - bp_out_root_mean_squared_error: 0.1926 - ecg_out_root_mean_squared_error: 0.1918
# Epoch 8/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0736 - bp_out_loss: 0.0368 - ecg_out_loss: 0.0368 - bp_out_root_mean_squared_error: 0.1919 - ecg_out_root_mean_squared_error: 0.1917
# Epoch 9/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0734 - bp_out_loss: 0.0366 - ecg_out_loss: 0.0368 - bp_out_root_mean_squared_error: 0.1914 - ecg_out_root_mean_squared_error: 0.1917
# Epoch 10/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0732 - bp_out_loss: 0.0365 - ecg_out_loss: 0.0367 - bp_out_root_mean_squared_error: 0.1910 - ecg_out_root_mean_squared_error: 0.1917
# Epoch 11/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0731 - bp_out_loss: 0.0364 - ecg_out_loss: 0.0367 - bp_out_root_mean_squared_error: 0.1908 - ecg_out_root_mean_squared_error: 0.1916
# Epoch 12/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0730 - bp_out_loss: 0.0363 - ecg_out_loss: 0.0367 - bp_out_root_mean_squared_error: 0.1906 - ecg_out_root_mean_squared_error: 0.1916
# Epoch 13/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0730 - bp_out_loss: 0.0363 - ecg_out_loss: 0.0367 - bp_out_root_mean_squared_error: 0.1904 - ecg_out_root_mean_squared_error: 0.1916
# Epoch 14/20
# 22/22 [==============================] - 41s 2s/step - loss: 0.0729 - bp_out_loss: 0.0362 - ecg_out_loss: 0.0367 - bp_out_root_mean_squared_error: 0.1903 - ecg_out_root_mean_squared_error: 0.1915
# Epoch 15/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0729 - bp_out_loss: 0.0362 - ecg_out_loss: 0.0367 - bp_out_root_mean_squared_error: 0.1902 - ecg_out_root_mean_squared_error: 0.1915
# Epoch 16/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0728 - bp_out_loss: 0.0362 - ecg_out_loss: 0.0367 - bp_out_root_mean_squared_error: 0.1902 - ecg_out_root_mean_squared_error: 0.1915
# Epoch 17/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0728 - bp_out_loss: 0.0361 - ecg_out_loss: 0.0367 - bp_out_root_mean_squared_error: 0.1901 - ecg_out_root_mean_squared_error: 0.1915
# Epoch 18/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0728 - bp_out_loss: 0.0361 - ecg_out_loss: 0.0367 - bp_out_root_mean_squared_error: 0.1900 - ecg_out_root_mean_squared_error: 0.1914
# Epoch 19/20
# 22/22 [==============================] - 40s 2s/step - loss: 0.0727 - bp_out_loss: 0.0361 - ecg_out_loss: 0.0366 - bp_out_root_mean_squared_error: 0.1900 - ecg_out_root_mean_squared_error: 0.1914
# Epoch 20/20
# 22/22 [==============================] - 41s 2s/step - loss: 0.0727 - bp_out_loss: 0.0361 - ecg_out_loss: 0.0366 - bp_out_root_mean_squared_error: 0.1899 - ecg_out_root_mean_squared_error: 0.1914

# %% [markdown]
# ### Evaluating CNN-LSTM model with Normalized ABP values

# %%
#Predicting on the test set using the LSTM model
CNN_LSTM_predictions_N = model.predict(X_test_PPG_N_reshape)
rmse = tf.keras.metrics.RootMeanSquaredError()
rmse.update_state(y_test_ABP_N, CNN_LSTM_predictions_N[0])
print(f'CNN-LSTM Model RMSE for Normalized ABP: {rmse.result().numpy()}')

# MAE for LSTM Model
MAE= tf.keras.metrics.MeanAbsoluteError()
MAE.update_state(y_test_ABP_N, CNN_LSTM_predictions_N[0])
print(f'CNN-LSTM Model MAE for Normalized ABP: {MAE.result().numpy()}')
# Out:
# 301/301 [==============================] - 9s 30ms/step
# CNN-LSTM Model RMSE for Normalized ABP: 0.18990275263786316
# CNN-LSTM Model MAE for Normalized ABP: 0.15428771078586578

# %% [markdown]
# ### Plotting graph for True vs Predicted Normalized ABP values using CNN-LSTM Model

# %%
# Visualize predicted BP and the True BP for LSTM model
plt.title("===True Vs Predicted Normalized ABP values in CNN-LSTM Model===")
plt.xlabel('Number of samples taken')
plt.ylabel('ABP values')
plt.plot(y_test_ABP_N[1000]) #only plotting 100 samples
plt.plot(CNN_LSTM_predictions_N[0][1000])
plt.legend(['True_BP', 'Predicted_BP'])

# %% [markdown]
# ### Evaluating CNN-LSTM model with Normalization for ECG values

# %%
rmse = tf.keras.metrics.RootMeanSquaredError()
rmse.update_state(y_test_ECG_N, CNN_LSTM_predictions_N[1])
print(f'CNN-LSTM Model RMSE for Normalized ECG: {rmse.result().numpy()}')

# MAE for LSTM Model
MAE= tf.keras.metrics.MeanAbsoluteError()
MAE.update_state(y_test_ECG_N, CNN_LSTM_predictions_N[1])
print(f'CNN-LSTM Model MAE for Normalized ECG: {MAE.result().numpy()}')
# Out:
# CNN-LSTM Model RMSE for Normalized ECG: 0.1906149834394455
# CNN-LSTM Model MAE for Normalized ECG: 0.14092309772968292

# %%
# Visualize predicted BP and the True BP for LSTM model
plt.title("===True ECG values Vs Predicted ECG values in CNN-LSTM Model With Normalized values===")
plt.xlabel('Number of samples taken')
plt.ylabel('ECG values')
plt.plot(y_test_ECG_N[1000]) #only plotting 100 samples
plt.plot(CNN_LSTM_predictions_N[1][1000])
plt.legend(['True_ECG', 'Predicted_ECG'])

# %% [markdown]
# ### CNN-LSTM Model with data augmentation

# %%
import numpy as np
from tensorflow.keras.utils import Sequence

class DataGenerator(Sequence):
    def __init__(self, x, y1, y2, batch_size=32, shuffle=True):
        self.x = x
        self.y1 = y1
        self.y2 = y2
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(x))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.x) / self.batch_size))

    def __getitem__(self, index):
        batch_indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        x_batch = self.x[batch_indexes]
        y1_batch = self.y1[batch_indexes]
        y2_batch = self.y2[batch_indexes]


        return x_batch, [y1_batch, y2_batch]

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %%
new_ppg= PPG_N.reshape((PPG_N.shape[0],PPG_N.shape[1],1))
new_ppg.shape
# Out:
# (32061, 1000, 1)

# %%
train_generator = DataGenerator(new_ppg, ABP_N, ECG_N, batch_size=1024)
validation_generator = DataGenerator(new_ppg, ABP_N, ECG_N, batch_size=1024, shuffle=False)

model.fit(train_generator,
          validation_data=validation_generator,
          epochs=20,
          steps_per_epoch=len(train_generator),
          validation_steps=len(validation_generator))
# Out:
# Epoch 1/20
# 32/32 [==============================] - 82s 3s/step - loss: 0.0726 - bp_out_loss: 0.0360 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1898 - ecg_out_root_mean_squared_error: 0.1912 - val_loss: 0.0726 - val_bp_out_loss: 0.0360 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1898 - val_ecg_out_root_mean_squared_error: 0.1911
# Epoch 2/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0726 - bp_out_loss: 0.0360 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1898 - ecg_out_root_mean_squared_error: 0.1911 - val_loss: 0.0725 - val_bp_out_loss: 0.0360 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1897 - val_ecg_out_root_mean_squared_error: 0.1911
# Epoch 3/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0725 - bp_out_loss: 0.0360 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1897 - ecg_out_root_mean_squared_error: 0.1911 - val_loss: 0.0725 - val_bp_out_loss: 0.0360 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1897 - val_ecg_out_root_mean_squared_error: 0.1911
# Epoch 4/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0725 - bp_out_loss: 0.0360 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1897 - ecg_out_root_mean_squared_error: 0.1911 - val_loss: 0.0725 - val_bp_out_loss: 0.0360 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1896 - val_ecg_out_root_mean_squared_error: 0.1911
# Epoch 5/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0724 - bp_out_loss: 0.0359 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1896 - ecg_out_root_mean_squared_error: 0.1911 - val_loss: 0.0724 - val_bp_out_loss: 0.0359 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1895 - val_ecg_out_root_mean_squared_error: 0.1911
# Epoch 6/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0724 - bp_out_loss: 0.0359 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1895 - ecg_out_root_mean_squared_error: 0.1911 - val_loss: 0.0724 - val_bp_out_loss: 0.0359 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1895 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 7/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0724 - bp_out_loss: 0.0359 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1895 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0724 - val_bp_out_loss: 0.0359 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1894 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 8/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0724 - bp_out_loss: 0.0359 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1894 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0724 - val_bp_out_loss: 0.0359 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1894 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 9/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0724 - bp_out_loss: 0.0359 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1894 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0723 - val_bp_out_loss: 0.0359 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1894 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 10/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0723 - bp_out_loss: 0.0358 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1893 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0723 - val_bp_out_loss: 0.0358 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1893 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 11/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0723 - bp_out_loss: 0.0358 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1893 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0723 - val_bp_out_loss: 0.0358 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1893 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 12/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0723 - bp_out_loss: 0.0358 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1893 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0723 - val_bp_out_loss: 0.0358 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1892 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 13/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0723 - bp_out_loss: 0.0358 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1892 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0723 - val_bp_out_loss: 0.0358 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1892 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 14/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0723 - bp_out_loss: 0.0358 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1892 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0723 - val_bp_out_loss: 0.0358 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1892 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 15/20
# 32/32 [==============================] - 78s 2s/step - loss: 0.0723 - bp_out_loss: 0.0358 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1892 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0723 - val_bp_out_loss: 0.0358 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1892 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 16/20
# 32/32 [==============================] - 78s 2s/step - loss: 0.0722 - bp_out_loss: 0.0358 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1891 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0722 - val_bp_out_loss: 0.0358 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1891 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 17/20
# 32/32 [==============================] - 78s 2s/step - loss: 0.0722 - bp_out_loss: 0.0358 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1891 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0722 - val_bp_out_loss: 0.0357 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1891 - val_ecg_out_root_mean_squared_error: 0.1910
# Epoch 18/20
# 32/32 [==============================] - 78s 2s/step - loss: 0.0722 - bp_out_loss: 0.0357 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1891 - ecg_out_root_mean_squared_error: 0.1910 - val_loss: 0.0722 - val_bp_out_loss: 0.0357 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1891 - val_ecg_out_root_mean_squared_error: 0.1909
# Epoch 19/20
# 32/32 [==============================] - 79s 2s/step - loss: 0.0722 - bp_out_loss: 0.0357 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1890 - ecg_out_root_mean_squared_error: 0.1909 - val_loss: 0.0722 - val_bp_out_loss: 0.0357 - val_ecg_out_loss: 0.0365 - val_bp_out_root_mean_squared_error: 0.1890 - val_ecg_out_root_mean_squared_error: 0.1909
# Epoch 20/20
# 32/32 [==============================] - 78s 2s/step - loss: 0.0722 - bp_out_loss: 0.0357 - ecg_out_loss: 0.0365 - bp_out_root_mean_squared_error: 0.1890 - ecg_out_root_mean_squared_error: 0.1909 - val_loss: 0.0722 - val_bp_out_loss: 0.0357 - val_ecg_out_loss: 0.0364 - val_bp_out_root_mean_squared_error: 0.1890 - val_ecg_out_root_mean_squared_error: 0.1909

# %% [markdown]
# ### Evaluating CNN-LSTM model with Augmented signal Values for ABP

# %%
#Predicting on the test set using the LSTM model
CNN_LSTM_predictions_augment = model.predict(X_test_PPG_N_reshape)
rmse = tf.keras.metrics.RootMeanSquaredError()
rmse.update_state(y_test_ABP_N, CNN_LSTM_predictions_augment[0])
print(f'CNN-LSTM Model RMSE for Augmented ABP: {rmse.result().numpy()}')

# MAE for LSTM Model
MAE= tf.keras.metrics.MeanAbsoluteError()
MAE.update_state(y_test_ABP_N, CNN_LSTM_predictions_augment[0])
print(f'CNN-LSTM Model MAE for Augented ABP: {MAE.result().numpy()}')
# Out:
# 301/301 [==============================] - 9s 30ms/step
# CNN-LSTM Model RMSE for Augmented ABP: 0.18904180824756622
# CNN-LSTM Model MAE for Augented ABP: 0.15344606339931488

# %%
# Visualize predicted BP and the True BP for LSTM model
plt.title("===True ABP values Vs Predicted BP values in CNN-LSTM Model With Augmented values===")
plt.xlabel('Number of samples taken')
plt.ylabel('ABP values')
plt.plot(y_test_ABP_N[1000]) #only plotting 100 samples
plt.plot(CNN_LSTM_predictions_augment[0][1000])
plt.legend(['True_ABP', 'Predicted_ABP'])

# %% [markdown]
# ### Evaluating CNN-LSTM model with Augmented ECG values

# %%
rmse = tf.keras.metrics.RootMeanSquaredError()
rmse.update_state(y_test_ECG_N, CNN_LSTM_predictions_augment[1])
print(f'CNN-LSTM Model RMSE for Augmented ECG: {rmse.result().numpy()}')

# MAE for LSTM Model
MAE= tf.keras.metrics.MeanAbsoluteError()
MAE.update_state(y_test_ECG_N, CNN_LSTM_predictions_augment[1])
print(f'CNN-LSTM Model MAE for Augmented ECG: {MAE.result().numpy()}')
# Out:
# CNN-LSTM Model RMSE for Augmented ECG: 0.19038531184196472
# CNN-LSTM Model MAE for Augmented ECG: 0.14145907759666443

# %%
# Visualize predicted BP and the True BP for LSTM model
plt.title("===True ECG values Vs Predicted ECG values in CNN-LSTM Model With Augmented values===")
plt.xlabel('Number of samples taken')
plt.ylabel('ECG values')
plt.plot(y_test_ECG_N[5]) #only plotting 100 samples
plt.plot(CNN_LSTM_predictions_augment[1][5])
plt.legend(['True_ECG', 'Predicted_ECG'])
